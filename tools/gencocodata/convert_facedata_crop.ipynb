# %% [markdown]
# # 将原图处理为Crop后的图像
#
# 更新：
# - 210607: 图像shape为`(height, width, channel)`，但labelme格式的points中坐标存储为`(x, y)`，其中x对应宽边，y对应高边，需要注意。
# - 210608: 训练报错: ERROR - The testing results of the whole dataset is empty.
#  - 参考<a>https://www.pythonf.cn/read/171511</a>可能是边框不能和图像边界重叠。
#  - 可能是被crop边界截断的标注的点阵顺序有问题，采用每次处理三个点（若处于同一条直线则删除中间点）的方式处理一下。
# - 210611: 注意circle标注本就只有两个点
# - 210611: 注意每次处理点的时候要进行`deepcopy`，`.copy()`只能复制一层，无法复制子对象

# %%
import os
import json
import numpy as np
import glob
import shutil
from sklearn.model_selection import train_test_split
np.random.seed(41)

import math
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import copy

import labelme.utils as lu


def originImageLoader(image_path):
    with open(image_path, encoding='utf-8') as json_file:
        labelmeJson = json.load(json_file)
        
        image = lu.img_b64_to_arr(labelmeJson['imageData'])
        image = image.astype(np.uint8)

        return image

#0为背景
dataset = 'skin'  # face, skin

if dataset == 'face':
    classname_to_id = {"brow": 1, "nose": 2, "mouth": 3}
    labelme_path = "E:/dataset/face/labelme/"
    saved_coco_path = "E:/dataset/face/"
elif dataset == 'skin':
    classname_to_id = {"closed_comedo": 1, "open_comedo": 2, "papule": 3, "pustule": 4, "nodule": 5,
        "atrophic_scar": 6, "hypertrophic_scar": 7, "melasma": 8, "nevus": 9, "other": 10}
    labelme_path = "E:/data_raw/skin/labelme"
    saved_coco_path = "E:/dataset/skin/"
    
class Lableme2CoCo:

    def __init__(self):
        self.images = []
        self.annotations = []
        self.categories = []
        self.img_id = 0
        self.ann_id = 0

    def save_coco_json(self, instance, save_path):
        json.dump(instance, open(save_path, 'w', encoding='utf-8'), ensure_ascii=False, indent=1)  # indent=2 更加美观显示

    def to_coco(self, json_path_list):
        '''
        由json文件构建COCO，不包括数据强化augment
        '''
        self._init_categories()
        for json_path in json_path_list:
            obj = self.read_jsonfile(json_path)
            # 处理图像信息
            self.images.append(self._image(obj, json_path))
            # 处理标注信息
            shapes = obj['shapes']
            for shape in shapes:
                annotation = self._annotation(shape)
                self.annotations.append(annotation)
                self.ann_id += 1
            self.img_id += 1
        instance = {}
        instance['info'] = 'spytensor created'
        instance['license'] = ['license']
        instance['images'] = self.images
        instance['annotations'] = self.annotations
        instance['categories'] = self.categories
        return instance
    
    def to_aug_coco(self, json_path_list, img_save_pre):
        '''
        由json文件构建COCO，不包括数据强化augment
        '''
        print('to_aug_coco start')
        self._init_categories()
        for json_path in json_path_list:
            print('handling: ', json_path)
            obj = self.read_jsonfile(json_path)
            sub_image_list, sub_annotation_list = self._relative_crop(obj = obj, 
                                                                      json_path = json_path, 
                                                                      img_save_pre = img_save_pre)
            self.images += sub_image_list
            self.annotations += sub_annotation_list
            
        instance = {}
        instance['info'] = 'spytensor created'
        instance['license'] = ['license']
        instance['images'] = self.images
        instance['annotations'] = self.annotations
        instance['categories'] = self.categories
        return instance
    
    def _relative_crop(self, obj, json_path, img_save_pre, img_scale=(2048,2048)):
        '''
        相对剪裁，类似于patch-based（好像是吧）,同时保存
        '''
        sub_image_list = []
        sub_annotation_list = []
        temp_block = []
        
        image_info = self._image(obj, json_path)
        # 处理图像信息
        num_h, num_w = math.ceil(image_info['height'] / img_scale[0]), math.ceil(image_info['width'] / img_scale[1])
        space_h = (image_info['height'] - img_scale[0]) / (num_h - 1)
        space_w = (image_info['width'] - img_scale[1]) / (num_w - 1)
        start_img_id = self.img_id
        
        img_numpy = originImageLoader(json_path)
        # 显示标注与图像
        '''
        img_whole = img_numpy.copy()
        shapes = obj['shapes']
        for shape in shapes:
            [x, y, w, h] = self._get_box(shape['points'])
            left_top = (int(x), int(y))
            right_bottom = (int(x+w), int(y+h))
            cv2.rectangle(img_whole, left_top, right_bottom, (0,255,0), thickness=3)
        plt.figure(figsize=(16,12))
        plt.imshow(img_whole)
        plt.show()
        '''
        print('image_info',image_info['height'],',',image_info['width'],'img_numpy: ',img_numpy.shape)
        for i in range(num_h):
            for j in range(num_w):
                image = {}
                image['height'], image['width'] = img_scale[0], img_scale[1]
                image['id'] = self.img_id + i * num_w + j
                image['file_name'] = os.path.basename(json_path).replace(".json", "")
                image['file_name'] += '_crop' + str(i * num_w + j) + ".jpg"
                # 额外添加的信息，代表相对原图分割的左上角位置
                image['crop_xy'] = [math.ceil(i*space_h), math.ceil(j*space_w)]
                # 保存图像
                
                im = Image.fromarray(img_numpy[image['crop_xy'][0]:image['crop_xy'][0]+img_scale[0],
                                    image['crop_xy'][1]:image['crop_xy'][1]+img_scale[1],:])
                im.save(img_save_pre + image['file_name'])
                
                sub_image_list.append(image)
                # 临时存储每个块的位置，包括坐上角点位和h,w
                temp_block.append((image['crop_xy'][0], image['crop_xy'][1]))
        # 处理标注信息
        shapes = obj['shapes']
        # print(temp_block)
        for shape in shapes:
            # 判断该标注的bbox在哪个（一个或多个）区域内
            # XXX: 注意顺序
            if shape['shape_type'] == "circle":
                points = shape['points']
                xy = [tuple(point) for point in points]
                (cx, cy), (px, py) = xy # 圆心和第二点
                # print(xy)
                # TODO：将圆形转换为多边形
                d = math.sqrt((cx - px) ** 2 + (cy - py) ** 2)
                d1 = math.sqrt((d ** 2) / 2)
                points = [[cx, cy-d], [cx-d1, cy-d1], [cx-d, cy], [cx-d1, cy+d1],
                         [cx, cy+d], [cx+d1, cy+d1], [cx+d, cy], [cx+d1, cy-d1]]
#                 print(points)
                shape['points'] = points
            [x, y, w, h] = self._get_box(shape['points'])
            for k, block in enumerate(temp_block):
                # 如果在该block的范围内
                
                if y>=block[0]-h and y<block[0]+img_scale[0] and x>=block[1]-w and x<block[1]+img_scale[1] :
                    # TODO: 这个特直接用copy根本就没有复制子对象
                    # shapes_item = shape.copy()
                    shapes_item = copy.deepcopy(shape)
                    effective_cnt = len(shapes_item['points'])
                    # 210610：处理被crop截断的标注可能出现的问题
#                     p0 = shapes_item['points'][0]
#                     p1 = shapes_item['points'][1]
#                     handled_points_list = [p0]
                    for kp, point in enumerate(shapes_item['points']):
                        point[0] -= block[1]
                        point[1] -= block[0]
#                         try:
#                             point[0] -= block[0]
#                             point[1] -= block[1]
#                         except:
#                             print(point[0],point[1],block[0],block[1],kp,point)
                        # 仅仅用bbox判断可能会出现错误，需要更严谨地判断
#                         if point[0]<=0 or point[0]>=img_scale[1] or point[1]<=0 or point[1]>=img_scale[0]:
#                             effective_cnt -= 1
#                         try:
#                             if point[0]<=0 or point[0]>=img_scale[0] or point[1]<=0 or point[1]>=img_scale[1]:
#                                 effective_cnt -= 1
#                         except:
#                             print(point[0],point[1],block[0],block[1],kp,point)
                        # 标注的边框可能不能和图像边框重合
                        point[0] = max(1, point[0])
                        point[0] = min(point[0], img_scale[1] - 1)
                        point[1] = max(1, point[1])
                        point[1] = min(point[1], img_scale[0] - 1)
#                         try:
#                             if kp >= 2 :
#                                 # 查看斜率的绝对误差
#                                 if abs((p0[1]-p1[1])/(p0[0]-p1[0]+100) - (p0[1]-point[1])/(p0[0]-point[0]+100)) < 0.0001:
#                                     # 则p1点不存入队列
#                                     p1 = point
#                                 else:
#                                     handled_points_list.append(p1)
#                                     p0 = p1
#                                     p1 = point
#                         except:
#                             print(p0[0],p0[1],p1[0],p1[1],point[0],point[1])
#                         if kp == len(shapes_item['points'])-1:
#                             p0 = handled_points_list[0]
#                             if abs((p0[1]-p1[1])/(p0[0]-p1[0]+100) - (p0[1]-point[1])/(p0[0]-point[0]+100)) < 0.0001:
#                                 # 则point点不存入队列
#                                 handled_points_list.append(p1)
#                             else:
#                                 handled_points_list += [p1, point]
                        shapes_item['points'][kp] = point
                    # 如果在范围内地点小于等于2个
#                     if effective_cnt <= 2:
#                         break
                    # print('>', end='')
                    self.img_id = start_img_id + k
                    annotation = self._annotation(shapes_item)
                    if annotation['bbox'][2] < 5 or annotation['bbox'][3] < 5:
                        continue
                    sub_annotation_list.append(annotation)
                    self.ann_id += 1
        self.img_id = start_img_id + num_h * num_w
        print(self.ann_id)
        # 调试用
        # self._show_image(img_numpy, sub_image_list, sub_annotation_list, (num_w, num_h))
        return sub_image_list, sub_annotation_list
    
    def _show_image(self, img_numpy, sub_image_list, sub_annotation_list, block_num, img_scale=(1024,1024)):
        '''
        通过coco数据格式显示标注与图像
        '''
        (num_w, num_h) = block_num
        plt.figure(figsize=(16,12))
        for k, image in enumerate(sub_image_list):
            im = img_numpy[image['crop_xy'][0]:image['crop_xy'][0]+img_scale[0], 
                           image['crop_xy'][1]:image['crop_xy'][1]+img_scale[1],:]
            for annotation in sub_annotation_list:
                if annotation['image_id'] == image['id']:
                    # print(annotation['segmentation'])
                    points = np.array(annotation['segmentation']).reshape(-1,2).tolist()
                    [x, y, w, h] = self._get_box(points)
                    left_top = (int(x), int(y))
                    right_bottom = (int(x+w), int(y+h))
                    cv2.rectangle(im, left_top, right_bottom, (0,255,0), thickness=3)
            plt.subplot(num_h, num_w, k+1)
            plt.imshow(im)
            plt.xticks([])  # 去掉横坐标值
            plt.yticks([])  # 去掉纵坐标值
        # plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0, hspace=0)
        plt.subplots_adjust(wspace=-0.6, hspace=0.1)
        plt.show()
    
    # 构建类别
    def _init_categories(self):
        '''
        根据全局变量classname_to_id构建类别
        '''
        for k, v in classname_to_id.items():
            category = {}
            category['id'] = v
            category['name'] = k
            self.categories.append(category)

    # 构建COCO的image字段
    def _image(self, obj, path):
        '''
        构建COCO的image字段：
        读取宽、高、名称，赋给id
        '''
        image = {}
        from labelme import utils
        img_x = utils.img_b64_to_arr(obj['imageData'])
        h, w = img_x.shape[:-1]
        image['height'] = h
        image['width'] = w
        image['id'] = self.img_id
        image['file_name'] = os.path.basename(path).replace(".json", ".jpg")
        return image

    # 构建COCO的annotation字段
    def _annotation(self, shape):
        label = shape['label']
        points = shape['points']
        annotation = {}
        if shape['shape_type'] != "circle" and shape['shape_type'] != "polygon":
            print(f'==================== ', shape['shape_type'], ' =====================')
        # TODO: to_coco与to_aug_coco关于点阵的处理位置不同
#         if shape['shape_type'] == "circle":
#             xy = [tuple(point) for point in points]
#             (cx, cy), (px, py) = xy # 圆心和第二点
#             # TODO：将圆形转换为多边形
#             d = math.sqrt((cx - px) ** 2 + (cy - py) ** 2)
#             d1 = math.sqrt((d ** 2) / 2)
#             points = [[cx, cy-d], [cx-d1, cy-d1], [cx-d, cy], [cx-d1, cy+d1],
#                      [cx, cy+d], [cx+d1, cy+d1], [cx+d, cy], [cx+d1, cy-d1]]
        
        annotation['id'] = self.ann_id
        annotation['image_id'] = self.img_id
#         if label == 'closecomedo':
#             annotation['category_id'] = 2
#         elif label == 'comedo w':
#             annotation['category_id'] = 2
#         elif label == 'comedo b':
#             annotation['category_id'] = 1
#         elif label == 'pigment':
#             annotation['category_id'] = 3
#         elif label == 'undifined':
#             annotation['category_id'] = 6
#         elif label == 'nodule':
#             annotation['category_id'] = 4
#         elif label == 'scar hyper':
#             annotation['category_id'] = 5
#         else :
#             annotation['category_id'] = int(classname_to_id[label])
        annotation['category_id'] = int(classname_to_id[label])
        annotation['segmentation'] = [np.asarray(points).flatten().tolist()]
        annotation['bbox'] = self._get_box(points)
        annotation['iscrowd'] = 0
        annotation['area'] = 1.0
        return annotation

    # 读取json文件，返回一个json对象
    def read_jsonfile(self, path):
        with open(path, "r", encoding='utf-8') as f:
            return json.load(f)

    # COCO的格式： [x1,y1,w,h] 对应COCO的bbox格式
    def _get_box(self, points):
        min_x = min_y = np.inf
        max_x = max_y = 0
        for x, y in points:
            min_x = min(min_x, x)
            min_y = min(min_y, y)
            max_x = max(max_x, x)
            max_y = max(max_y, y)
        return [min_x, min_y, max_x - min_x, max_y - min_y]

# %%
if __name__ == '__main__':
    
    # 创建文件
    if not os.path.exists("%scoco1/annotations/"%saved_coco_path):
        os.makedirs("%scoco1/annotations/"%saved_coco_path)
    if not os.path.exists("%scoco1/images/train2017/"%saved_coco_path):
        os.makedirs("%scoco1/images/train2017"%saved_coco_path)
    if not os.path.exists("%scoco1/images/val2017/"%saved_coco_path):
        os.makedirs("%scoco1/images/val2017"%saved_coco_path)
    # 获取images目录下所有的joson文件列表
    json_list_path = glob.glob(labelme_path + "/*.json")
    # 数据划分,这里没有区分val2017和tran2017目录，所有图片都放在images目录下
    train_path, val_path = train_test_split(json_list_path, test_size=0.2)
    
    if dataset == 'face':
        train_path = train_path + val_path
        val_path = []
    
    # 用于测试模型是否能够过拟合
    # rest_path, train_path = train_test_split(json_list_path, test_size=0.05)
    # _, val_path = train_test_split(rest_path, test_size=0.05)
    print(train_path)
    print(val_path)
    print("train_n:", len(train_path), 'val_n:', len(val_path))

    # 把训练集转化为COCO的json格式
    l2c_train = Lableme2CoCo()
    # train_instance = l2c_train.to_coco(train_path)
    train_instance = l2c_train.to_aug_coco(train_path, "%scoco1/images/train2017/"%saved_coco_path)
    l2c_train.save_coco_json(train_instance, '%scoco1/annotations/instances_train2017.json'%saved_coco_path)
    '''
    for file in train_path:
        # shutil.copy(file.replace("json","jpg"),"%scoco/images/train2017/"%saved_coco_path)
        im = Image.fromarray(originImageLoader(file))
        file_name = file.split("\\")[-1]
        file_name = file_name.replace("json","jpg")
        im.save("%scoco/images/train2017/"%saved_coco_path + file_name)
    for file in val_path:
        # shutil.copy(file.replace("json","jpg"),"%scoco/images/val2017/"%saved_coco_path)
        im = Image.fromarray(originImageLoader(file))
        file_name = file.split("\\")[-1]
        file_name = file_name.replace("json","jpg")
        im.save("%scoco/images/val2017/"%saved_coco_path + file_name)
    '''
    # 把验证集转化为COCO的json格式
    l2c_val = Lableme2CoCo()
    # val_instance = l2c_val.to_coco(val_path)
    val_instance = l2c_val.to_aug_coco(val_path, "%scoco1/images/val2017/"%saved_coco_path)
    l2c_val.save_coco_json(val_instance, '%scoco1/annotations/instances_val2017.json'%saved_coco_path)
# Out:
# ['E:/data_raw/skin/labelme\\J__任科宇_痤疮_20190130143112000_斑点.json', 'E:/data_raw/skin/labelme\\J__安妮_痤疮_20190226083127000_斑点.json', 'E:/data_raw/skin/labelme\\J__夏梦旭_痤疮_20191230111741000_斑点.json', 'E:/data_raw/skin/labelme\\J__李亚玲_痤疮_20190220131753000_斑点.json', 'E:/data_raw/skin/labelme\\CXM__严仁杰_痤疮_20190816103212000_斑点.json', 'E:/data_raw/skin/labelme\\J__康禾_痤疮PIH_20190319091700000_斑点.json', 'E:/data_raw/skin/labelme\\J__余泓颖_痤疮_20190220103433000_斑点.json', 'E:/data_raw/skin/labelme\\J__康禾_痤疮_20190416094801000_斑点.json', 'E:/data_raw/skin/labelme\\CXM__高美玲_痤疮_20190821102141000_斑点.json', 'E:/data_raw/skin/labelme\\J__侯玥颖_痤�
in/labelme\\J__代龙建_痤疮_20190410101039000_斑点.json', 'E:/data_raw/skin/labelme\\J__黄勋_痤疮_20190402093822000_斑点.json', 'E:/data_raw/skin/labelme\\J__屈艳_痤疮_20190604084209000_斑点.json', 'E:/data_raw/skin/labelme\\J__熊俊任_痤疮_20190108102432000_斑点.json', 'E:/data_raw/skin/labelme\\CXM__何浩淼_痤疮毛囊炎_20190808083431000_斑点.json', 'E:/data_raw/skin/labelme\\J__申晓轩_痤疮_20200630084308000_斑点.json', 'E:/data_raw/skin/labelme\\J__代自豪_痤疮_20190423093626000_斑点.json', 'E:/data_raw/skin/labelme\\J__岳丹琳_痤疮_20201019111940000_标准照片.json', 'E:/data_raw/skin/labelme\\CXM__黄黎敬_痤疮_20191007134504000_斑点.json', 'E:/data_raw/skin/labelme\\J__张倬_痤疮疤痕_20190116132209000_斑点.json', 'E:/data_raw/skin/labelme\\J__宋卓恒_痤疮_20200722090123000_斑点.json', 'E:/data_raw/skin/labelme\\J__何云英_痤疮_20190320083511000_斑点.json', 'E:/data_raw/skin/labelme\\J__宋官飞_痤疮_20190108103914000_斑点.json', 'E:/data_raw/skin/labelme\\J__刘懿_痤疮_20190227105740000_斑点.json', 'E:/data_raw/skin/labelme\\CXM__龚超_痤疮_20191107102053000_斑点.json', 'E:/data_raw/skin/labelme\\J__杨尧_痤疮_20190108091139000_斑点.json', 'E:/data_raw/skin/labelme\\J__任芸锋痤疮_20190813102320000_斑点.json', 'E:/data_raw/skin/labelme\\CXM__王栎鑫_痤疮_20191220142049000_斑点.json']
# train_n: 132 val_n: 33
# to_aug_coco start
# handling:  E:/data_raw/skin/labelme\J__任科宇_痤疮_20190130143112000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 126
# handling:  E:/data_raw/skin/labelme\J__安妮_痤疮_20190226083127000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 203
# handling:  E:/data_raw/skin/labelme\J__夏梦旭_痤疮_20191230111741000_斑点.json
# image_info 4171 , 3128 img_numpy:  (4171, 3128, 3)
# 390
# handling:  E:/data_raw/skin/labelme\J__李亚玲_痤疮_20190220131753000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 466
# handling:  E:/data_raw/skin/labelme\CXM__严仁杰_痤疮_20190816103212000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 538
# handling:  E:/data_raw/skin/labelme\J__康禾_痤疮PIH_20190319091700000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 724
# handling:  E:/data_raw/skin/labelme\J__余泓颖_痤疮_20190220103433000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 845
# handling:  E:/data_raw/skin/labelme\J__康禾_痤疮_20190416094801000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 970
# handling:  E:/data_raw/skin/labelme\CXM__高美玲_痤疮_20190821102141000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 1168
# handling:  E:/data_raw/skin/labelme\J__侯玥颖_痤疮_20191030103240000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 1245
# handling:  E:/data_raw/skin/labelme\J__蔡晓舟_痤疮_20190220104205000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 1382
# handling:  E:/data_raw/skin/labelme\J__尹洁_痤疮_20190227094716000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 1548
# handling:  E:/data_raw/skin/labelme\J__陈乙_痤疮_20191030102140000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 1749
# handling:  E:/data_raw/skin/labelme\CXM__周琦雨_痤疮_20200910154351000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 1903
# handling:  E:/data_raw/skin/labelme\J__蔡炜_痤疮_20190130134832000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 1903
# handling:  E:/data_raw/skin/labelme\J__庞博_痤疮_20200908111844000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 1936
# handling:  E:/data_raw/skin/labelme\J__尹有艳_痤疮_20200526111543000_斑点.json
# image_info 4171 , 3128 img_numpy:  (4171, 3128, 3)
# 2032
# handling:  E:/data_raw/skin/labelme\GZP__郭姗_痤疮_20200928100207000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 2097
# handling:  E:/data_raw/skin/labelme\J__官见生_痤疮_20200630083659000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 2243
# handling:  E:/data_raw/skin/labelme\J__岳钰婷痤疮_20190710093347000_标准照片.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 2318
# handling:  E:/data_raw/skin/labelme\J__岳钰婷_痤疮_20190604080805000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 2384
# handling:  E:/data_raw/skin/labelme\J__侯志伟_痤疮_20190522151706000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 2384
# handling:  E:/data_raw/skin/labelme\JX__刘严木_痤疮_20200511095342000_斑点.json
# image_info 4171 , 3128 img_numpy:  (4171, 3128, 3)
# 2537
# handling:  E:/data_raw/skin/labelme\CXM__颜竹青_痤疮_20191101141351000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 2703
# handling:  E:/data_raw/skin/labelme\J__任丽_痤疮_20190410102305000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 3007
# handling:  E:/data_raw/skin/labelme\J__刘杨_痤疮_20190527111449000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 3287
# handling:  E:/data_raw/skin/labelme\J__王泽亚_痤疮_20191023093023000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 3402
# handling:  E:/data_raw/skin/labelme\J__康浩然_痤疮_20190130095052000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 3511
# handling:  E:/data_raw/skin/labelme\CXM__杨春艳_痤疮_20200813144226000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 3742
# handling:  E:/data_raw/skin/labelme\J__任艺_痤疮_20200915090331000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 3852
# handling:  E:/data_raw/skin/labelme\CXM__余丹_痤疮_20200821081008000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 4144
# handling:  E:/data_raw/skin/labelme\J__位思桐_痤疮_20201021093755000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 4481
# handling:  E:/data_raw/skin/labelme\J__代敏_痤疮_20191225082918000_斑点.json
# image_info 4171 , 3128 img_numpy:  (4171, 3128, 3)
# 4681
# handling:  E:/data_raw/skin/labelme\J__陈雪峰_痤疮_20190305102113000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 4681
# handling:  E:/data_raw/skin/labelme\J__黄韵洁_痤疮_20190220161303000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 4778
# handling:  E:/data_raw/skin/labelme\J__何刘平_痤疮_20190115094820000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 4778
# handling:  E:/data_raw/skin/labelme\CXM__闫春林_痤疮_20200925104436000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 4944
# handling:  E:/data_raw/skin/labelme\CXM__马丽肖_痤疮_20191219094320000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 4974
# handling:  E:/data_raw/skin/labelme\J__宋欧_痤疮_20200825091725000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 5075
# handling:  E:/data_raw/skin/labelme\CXM__但郁琳_痤疮_20190826141434000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 5175
# handling:  E:/data_raw/skin/labelme\J__姜垠宏_痤疮_20200505082937000_斑点.json
# image_info 4171 , 3128 img_numpy:  (4171, 3128, 3)
# 5268
# handling:  E:/data_raw/skin/labelme\J__刘嘉玲_痤疮_20190123090437000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 5478
# handling:  E:/data_raw/skin/labelme\J__崔健_痤疮_20190313144151000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 5628
# handling:  E:/data_raw/skin/labelme\J__陈超_痤疮_20190128085910000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 5628
# handling:  E:/data_raw/skin/labelme\CXM__张姝怡_痤疮_20190822094248000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 5794
# handling:  E:/data_raw/skin/labelme\J__任鹏锦_痤疮_20190430112412000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 5942
# handling:  E:/data_raw/skin/labelme\J__安妮_痤疮_20190109090517000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 6022
# handling:  E:/data_raw/skin/labelme\CXM__连晓芬_痤疮_20191007105037000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 6022
# handling:  E:/data_raw/skin/labelme\J__尉超_痤疮_20190904082707000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 6132
# handling:  E:/data_raw/skin/labelme\J__陈阳_痤疮_20190911133534000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 6132
# handling:  E:/data_raw/skin/labelme\J__张倩_痤疮_20190904151744000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 6224
# handling:  E:/data_raw/skin/labelme\CXM__丁旭_痤疮_20191104152233000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 6345
# handling:  E:/data_raw/skin/labelme\J__岳钰婷_痤疮_20190507102108000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 6401
# handling:  E:/data_raw/skin/labelme\J__伍宇婷_痤疮_20191029094512000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 6679
# handling:  E:/data_raw/skin/labelme\J__夏成易_痤疮_20190220093134000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 6776
# handling:  E:/data_raw/skin/labelme\CXM__谢政廷_痤疮_20200903095849000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 6928
# handling:  E:/data_raw/skin/labelme\CXM__高彦琳_痤疮_20191004140821000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 7026
# handling:  E:/data_raw/skin/labelme\J__姚婷_痤疮_20200429105255000_斑点.json
# image_info 4171 , 3128 img_numpy:  (4171, 3128, 3)
# 7120
# handling:  E:/data_raw/skin/labelme\J__刘政廷_痤疮_20200825083632000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 7376
# handling:  E:/data_raw/skin/labelme\CXM__文雷_痤疮_20200702135838000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 7616
# handling:  E:/data_raw/skin/labelme\J__岳钰婷_痤疮_20190226100021000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 7673
# handling:  E:/data_raw/skin/labelme\J__张亚婷_痤疮_20190917080822000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 7775
# handling:  E:/data_raw/skin/labelme\J__夏林欢痤疮_20190723151742000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 7854
# handling:  E:/data_raw/skin/labelme\GZP__谭笑_痤疮_20200602084559000_斑点.json
# image_info 4171 , 3128 img_numpy:  (4171, 3128, 3)
# 8110
# handling:  E:/data_raw/skin/labelme\J__刘栩男_痤疮_20201013083236000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 8194
# handling:  E:/data_raw/skin/labelme\CXM__刘伟_痤疮_20190816142222000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 8509
# handling:  E:/data_raw/skin/labelme\GZP__李妮_痤疮_20200922094212000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 8523
# handling:  E:/data_raw/skin/labelme\J__刘双中_痤疮_20190410134617000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 8642
# handling:  E:/data_raw/skin/labelme\J__张万玲_痤疮_20190416094153000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 8854
# handling:  E:/data_raw/skin/labelme\J__代敏_痤疮_20200707090509000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 9010
# handling:  E:/data_raw/skin/labelme\J__岳钰婷_痤疮_20190116114334000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 9127
# handling:  E:/data_raw/skin/labelme\J__代敏_痤疮_20201013113140000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 9293
# handling:  E:/data_raw/skin/labelme\CXM__陈荣荣_痤疮_20191011081639000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 9402
# handling:  E:/data_raw/skin/labelme\J__孙子媛_痤疮_20200707110214000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 9538
# handling:  E:/data_raw/skin/labelme\CXM__何韵_痤疮_20200828103300000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 9789
# handling:  E:/data_raw/skin/labelme\CXM__刘刁刁_痤疮_20200917144814000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
#
_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 1473
# handling:  E:/data_raw/skin/labelme\J__李陈_痤疮_20190122112959000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 1720
# handling:  E:/data_raw/skin/labelme\J__孟怡洁_痤疮_20191030095016000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 1821
# handling:  E:/data_raw/skin/labelme\J__谢柠枍_痤疮_20190130132512000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 1943
# handling:  E:/data_raw/skin/labelme\CXM__黎晓明_痤疮_20201008134406000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 2081
# handling:  E:/data_raw/skin/labelme\GZP__蒲睿琪_痤疮_20200512082250000_斑点.json
# image_info 4171 , 3128 img_numpy:  (4171, 3128, 3)
# 2212
# handling:  E:/data_raw/skin/labelme\J__代龙建_痤疮_20190410101039000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 2446
# handling:  E:/data_raw/skin/labelme\J__黄勋_痤疮_20190402093822000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 2579
# handling:  E:/data_raw/skin/labelme\J__屈艳_痤疮_20190604084209000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 2640
# handling:  E:/data_raw/skin/labelme\J__熊俊任_痤疮_20190108102432000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 3111
# handling:  E:/data_raw/skin/labelme\CXM__何浩淼_痤疮毛囊炎_20190808083431000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 3384
# handling:  E:/data_raw/skin/labelme\J__申晓轩_痤疮_20200630084308000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 3654
# handling:  E:/data_raw/skin/labelme\J__代自豪_痤疮_20190423093626000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 3837
# handling:  E:/data_raw/skin/labelme\J__岳丹琳_痤疮_20201019111940000_标准照片.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 3934
# handling:  E:/data_raw/skin/labelme\CXM__黄黎敬_痤疮_20191007134504000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 4032
# handling:  E:/data_raw/skin/labelme\J__张倬_痤疮疤痕_20190116132209000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 4206
# handling:  E:/data_raw/skin/labelme\J__宋卓恒_痤疮_20200722090123000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 4288
# handling:  E:/data_raw/skin/labelme\J__何云英_痤疮_20190320083511000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 4677
# handling:  E:/data_raw/skin/labelme\J__宋官飞_痤疮_20190108103914000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 4976
# handling:  E:/data_raw/skin/labelme\J__刘懿_痤疮_20190227105740000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 5153
# handling:  E:/data_raw/skin/labelme\CXM__龚超_痤疮_20191107102053000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 5264
# handling:  E:/data_raw/skin/labelme\J__杨尧_痤疮_20190108091139000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 5264
# handling:  E:/data_raw/skin/labelme\J__任芸锋痤疮_20190813102320000_斑点.json
# image_info 4600 , 3448 img_numpy:  (4600, 3448, 3)
# 5539
# handling:  E:/data_raw/skin/labelme\CXM__王栎鑫_痤疮_20191220142049000_斑点.json
# image_info 5184 , 3456 img_numpy:  (5184, 3456, 3)
# 5678

# %%
print(len(train_path))
print(len(val_path))
# Out:
# 132
# 33

# %%
test_path = '/home/wangjy/research/maskrcnn/facedata/CXM, #U5218#U5201#U5201-#U75e4#U75ae 20200917144814000 #U6591#U70b9.json'
test_image = originImageLoader(test_path)

# %%
import os
check_path_img_train = '/home/wangjy/data/facedata_croped/coco/images/train2017/'
check_path_img_val = '/home/wangjy/data/facedata_croped/coco/images/val2017/'
check_list_img_train = os.listdir(check_path_img_train)
check_list_img_val = os.listdir(check_path_img_val)
print(len(check_list_img_train))
print(len(check_list_img_val))

check_path_label_train = '/home/wangjy/data/facedata_croped/coco/annotations/'
# Out:
# 2496
# 340
